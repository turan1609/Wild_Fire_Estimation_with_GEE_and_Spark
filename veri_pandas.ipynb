# %%
import findspark
findspark.init()
import pandas as pd

# O uzun dosya ismini kopyalamana gerek yok, klasörü okuması yeterli.
# Pandas klasörü gösterince içindeki parquet'yi bulur.
df_pandas = pd.read_parquet("../data/processed/ALAZ_Final_Dataset_Cleaned.parquet")

print(f"Satır Sayısı: {len(df_pandas)}")
print("İşte Verimizin Son Hali:")

# İlk 10 satırı göster (Excel gibi tablo yapar)
display(df_pandas.head(10))

# Rastgele 5 örnek getir (Verinin içinden rastgele seçer)
print("Rastgele Örnekler:")
display(df_pandas.sample(50))
# Out:
# Satır Sayısı: 370100
# İşte Verimizin Son Hali:
#     latitude  longitude       tarih  saat  yukselti  egim   baki   sicaklik  \
# 0  40.229349  34.341218  2006-04-05     2     955.0   3.0  149.0   2.112955
# 1  38.049991  40.058694  2003-06-01    17     701.0   2.0   51.0  19.191034
# 2  37.306732  43.795264  2016-08-08    15    1840.0  15.0  171.0  26.386972
# 3  38.917172  34.253927  2006-08-31    14     868.0   1.0  225.0  33.772119
# 4  38.723600  28.495086  2013-12-24     9     421.0   4.0    1.0   6.459894
# 5  38.023384  28.007027  2005-03-16     9     934.0  14.0  218.0  10.033990
# 6  38.008062  32.489440  2022-01-29     2    1250.0   4.0   93.0 -12.080313
# 7  39.383235  31.967285  2001-01-22    23     743.0   1.0   94.0  -1.801855
# 8  41.629593  41.692113  2015-01-25     1     183.0  12.0  278.0   4.498056
# 9  39.491622  42.499581  2006-03-06     5    1870.0   3.0   49.0  -7.351752
#
#    ruzgar_hizi  bagil_nem     yagis  toprak_sicakligi    NDVI  label
# ...

# %%
df
